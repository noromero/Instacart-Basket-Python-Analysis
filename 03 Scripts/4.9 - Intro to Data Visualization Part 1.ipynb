# %% [markdown]
# # Table of Contents
#
# Part 1 Exercise
#
# - Imported and performed data checks on new customers CSV
#
# - Performed cleaning on ords_prods_merge file. Removed left_only merge rows and merge indicator columns
#
# - Combined clean ords_prods file with wrangled customers csv

# %% [markdown]
# ### Step 3
#
# Import your analysis libraries, as well as your new customer data set as a dataframe.

# %%
# importing libraries

import pandas as pd
import numpy as np
import os

# setting master path
path = r'/Users/Norberto/Desktop/2023-10 Instacart Basket Analysis'

# %%
# read pkl file
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
# read customer data file
customers_df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'))

# %% [markdown]
# ### Step 4
# Wrangle the data so that it follows consistent logic; for example, rename columns with illogical names and drop columns that don’t add anything to your analysis.

# %%
# display first table to see what data looks like
customers_df.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
# rename column in dataframe
customers_df.rename(columns = {'First Name' : 'first_name', 
                               'Surnam' : 'surname', 
                               'Gender' : 'gender', 
                               'STATE' : 'state',
                               'Age' : 'age',
                               'n_dependants' : 'num_depend'
                              }, inplace = True)

# %%
# confirm changes were made
customers_df.head()
# Out:
#    user_id first_name   surname  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    num_depend fam_status  income
# 0           3    married  165665
# 1           0     single   59285
# 2           2    married   99568
# 3           0     single   42049
# 4           1    married   40374

# %%
# drop unecessary columns
customers_df = customers_df.drop(columns = ['date_joined', 'first_name', 'surname'])

# %%
# confirm changes were made
customers_df.head()
# Out:
#    user_id  gender       state  age  num_depend fam_status  income
# 0    26711  Female    Missouri   48           3    married  165665
# 1    33890  Female  New Mexico   36           0     single   59285
# 2    65803    Male       Idaho   35           2    married   99568
# 3   125935  Female        Iowa   40           0     single   42049
# 4   130797  Female    Maryland   26           1    married   40374

# %%
# look at numerical stats to check for irregularities
customers_df.describe()
# Out:
#              user_id            age     num_depend         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %%
# change user_id to str and check data types after to confirm
customers_df['user_id'] = customers_df['user_id'].astype('str')
customers_df.dtypes
# Out:
# user_id       object
# gender        object
# state         object
# age            int64
# num_depend     int64
# fam_status    object
# income         int64
# dtype: object

# %% [markdown]
# ### Step 5
#
# Complete the fundamental data quality and consistency checks you’ve learned throughout this Achievement; for example, check for and address missing values and duplicates, and convert any mixed-type data.

# %%
# check for null values
customers_df.isnull().sum()
# Out:
# user_id       0
# gender        0
# state         0
# age           0
# num_depend    0
# fam_status    0
# income        0
# dtype: int64

# %%
# check for duplicates
dup_cust_df = customers_df[customers_df.duplicated()]
dup_cust_df
# Out:
# Empty DataFrame
# Columns: [user_id, gender, state, age, num_depend, fam_status, income]
# Index: []

# %%
# check for columns with inconsistent data types
for col in customers_df.columns.tolist():
  weird = (customers_df[[col]].applymap(type) != customers_df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (customers_df[weird]) > 0:
    print (col)

# %%
# look at numerical columns for statistical analysis
customers_df.describe()
# Out:
#                  age     num_depend         income
# count  206209.000000  206209.000000  206209.000000
# mean       49.501646       1.499823   94632.852548
# std        18.480962       1.118433   42473.786988
# min        18.000000       0.000000   25903.000000
# 25%        33.000000       0.000000   59874.000000
# 50%        49.000000       1.000000   93547.000000
# 75%        66.000000       3.000000  124244.000000
# max        81.000000       3.000000  593901.000000

# %% [markdown]
# The three available numerical values are displayed correctly as per the describe function. The age, with a minimum of 18 and max of 81 is expected with app usage restrictions. Number of dependants makes sense, with no values below 0, and incomes seem to be reported within reasonable limits. Earlier, the user_id field was changed to a str so that it wouldn't generate numerical stats.

# %% [markdown]
# ### Step 6
# Combine your customer data with the rest of your prepared Instacart data. (Hint: Make sure the key columns are the same data type!)

# %%
# Look at shape and head of customers DF
customers_df_shape = customers_df.shape
print(customers_df_shape)
customers_df.head(15)
# Out:
# (206209, 7)
#    user_id  gender           state  age  num_depend  \
# 0    26711  Female        Missouri   48           3
# 1    33890  Female      New Mexico   36           0
# 2    65803    Male           Idaho   35           2
# 3   125935  Female            Iowa   40           0
# 4   130797  Female        Maryland   26           1
# 5   133128  Female        Kentucky   43           2
# 6   152052    Male         Montana   20           0
# 7   168851    Male  South Carolina   30           0
# 8    69965    Male           Texas   47           1
# 9    82820    Male        Virginia   26           2
# 10   26441  Female          Nevada   19           2
# 11   33835    Male        Nebraska   45           2
# 12   75032  Female         Georgia   75           1
# 13      51  Female         Wyoming   37           1
# 14     516    Male        Colorado   51           2
#
#                           fam_status  income
# 0                            married  165665
# 1                             single   59285
# 2                            married   99568
# 3                             single   42049
# 4                            married   40374
# 5                            married   49643
# 6                             single   61746
# 7                             single   63712
# 8                            married  162432
# 9                            married   32072
# 10  living with parents and siblings   43443
# 11                           married   47988
# 12                           married   57835
# 13                           married   71190
# 14                           married  146559

# %%
# confirm data types of customers DF
customers_df.dtypes
# Out:
# user_id       object
# gender        object
# state         object
# age            int64
# num_depend     int64
# fam_status    object
# income         int64
# dtype: object

# %%
# read pkl file
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
# Look at shape and head of ords_prods df
ords_prods_shape = ords_prods_merge.shape
print(ords_prods_shape)
ords_prods_merge.head(15)
# Out:
# (32435059, 24)
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 3    2539329        1             1                   2                  8
# 4    2539329        1             1                   2                  8
# 5    2398795        1             2                   3                  7
# 6    2398795        1             2                   3                  7
# 7    2398795        1             2                   3                  7
# 8    2398795        1             2                   3                  7
# 9    2398795        1             2                   3                  7
# 10   2398795        1             2                   3                  7
# 11    473747        1             3                   3                 12
# 12    473747        1             3                   3                 12
# 13    473747        1             3                   3                 12
# 14    473747        1             3                   3                 12
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN         196                  1          0
# 1                      NaN       14084                  2          0
# 2                      NaN       12427                  3          0
# 3                      NaN       26088                  4          0
# 4                      NaN       26405                  5          0
# 5                     15.0         196                  1          1
# 6                     15.0       10258                  2          0
# 7                     15.0       12427                  3          1
# 8                     15.0       13176                  4          0
# 9                     15.0       26088                  5          1
# 10                    15.0       13032                  6          0
# 11                    21.0         196                  1          1
# 12                    21.0       12427                  2          1
# 13                    21.0       10258                  3          1
# 14                    21.0       25133                  4          0
#
#                                product_name  ...    price_range_loc  \
# 0                                      Soda  ...  Mid-range product
# 1   Organic Unsweetened Vanilla Almond Milk  ...  Mid-range product
# 2                       Original Beef Jerky  ...  Low-range product
# 3                Aged White Cheddar Popcorn  ...  Low-range product
# 4          XL Pick-A-Size Paper Towel Rolls  ...  Low-range product
# 5                                      Soda  ...  Mid-range product
# 6                                Pistachios  ...  Low-range product
# 7                       Original Beef Jerky  ...  Low-range product
# 8                    Bag of Organic Bananas  ...  Mid-range product
# 9                Aged White Cheddar Popcorn  ...  Low-range product
# 10                    Cinnamon Toast Crunch  ...  Low-range product
# 11                                     Soda  ...  Mid-range product
# 12                      Original Beef Jerky  ...  Low-range product
# 13                               Pistachios  ...  Low-range product
# 14                    Organic String Cheese  ...  Mid-range product
#
#        busiest_day  busiest_day_new busiest_period_of_day max_order  \
# 0   Regularly busy   Regularly busy        Average orders        10
# 1   Regularly busy   Regularly busy        Average orders        10
# 2   Regularly busy   Regularly busy        Average orders        10
# 3   Regularly busy   Regularly busy        Average orders        10
# 4   Regularly busy   Regularly busy        Average orders        10
# 5   Regularly busy       Least busy        Average orders        10
# 6   Regularly busy       Least busy        Average orders        10
# 7   Regularly busy       Least busy        Average orders        10
# 8   Regularly busy       Least busy        Average orders        10
# 9   Regularly busy       Least busy        Average orders        10
# 10  Regularly busy       Least busy        Average orders        10
# 11  Regularly busy       Least busy           Most orders        10
# 12  Regularly busy       Least busy           Most orders        10
# 13  Regularly busy       Least busy           Most orders        10
# 14  Regularly busy       Least busy           Most orders        10
#
#     loyalty_flag avg_spending spending_flag  dspo_median  \
# 0   New customer     6.367797  High Spender         20.5
# 1   New customer     6.367797  High Spender         20.5
# 2   New customer     6.367797  High Spender         20.5
# 3   New customer     6.367797  High Spender         20.5
# 4   New customer     6.367797  High Spender         20.5
# 5   New customer     6.367797  High Spender         20.5
# 6   New customer     6.367797  High Spender         20.5
# 7   New customer     6.367797  High Spender         20.5
# 8   New customer     6.367797  High Spender         20.5
# 9   New customer     6.367797  High Spender         20.5
# 10  New customer     6.367797  High Spender         20.5
# 11  New customer     6.367797  High Spender         20.5
# 12  New customer     6.367797  High Spender         20.5
# 13  New customer     6.367797  High Spender         20.5
# 14  New customer     6.367797  High Spender         20.5
#
#      order_frequency_flag
# 0   Non-frequent customer
# 1   Non-frequent customer
# 2   Non-frequent customer
# 3   Non-frequent customer
# 4   Non-frequent customer
# 5   Non-frequent customer
# 6   Non-frequent customer
# 7   Non-frequent customer
# 8   Non-frequent customer
# 9   Non-frequent customer
# 10  Non-frequent customer
# 11  Non-frequent customer
# 12  Non-frequent customer
# 13  Non-frequent customer
# 14  Non-frequent customer
#
# [15 rows x 24 columns]

# %% [markdown]
# ### ORDS_PRODS_MERGE Data Checks
# - Wrangle the data so that it follows consistent logic; for example, rename columns with illogical names and drop columns that don’t add anything to your analysis.
# - Complete the fundamental data quality and consistency checks you’ve learned throughout this Achievement; for example, check for and address missing values and duplicates, and convert any mixed-type data.

# %%
# check data types on ords_prods df
ords_prods_merge.dtypes
# Out:
# order_id                     int64
# user_id                      int64
# order_number                 int64
# orders_day_of_week           int64
# order_hour_of_day            int64
# days_since_prior_order     float64
# product_id                   int64
# add_to_cart_order            int64
# reordered                    int64
# product_name                object
# aisle_id                   float64
# department_id              float64
# prices                     float64
# _merge                    category
# price_range_loc             object
# busiest_day                 object
# busiest_day_new             object
# busiest_period_of_day       object
# max_order                    int64
# loyalty_flag                object
# avg_spending               float64
# spending_flag               object
# dspo_median                float64
# order_frequency_flag        object
# dtype: object

# %%
# update user_id to 'str' for merging
ords_prods_merge['user_id'] = ords_prods_merge['user_id'].astype('str')

# %%
# create new df with all 'left_only' values from df
df_left = ords_prods_merge[ords_prods_merge['_merge']=='left_only']
df_left
# Out:
#           order_id user_id  order_number  orders_day_of_week  \
# 2963          7099      27            63                   3
# 3205       1837192      27            80                   2
# 3253       3331846      28             3                   0
# 3395       1385910      28            21                   2
# 4694       2873174      38             1                   0
# ...            ...     ...           ...                 ...
# 32425294    443233  206139             2                   1
# 32425300   1507543  206139             3                   1
# 32427098   1282274  206155             4                   6
# 32431906   1586626  206194             9                   1
# 32431929     56974  206194            11                   5
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 2963                     10                     1.0        6799
# 3205                      8                     6.0        6799
# 3253                     16                     2.0          34
# 3395                     17                     1.0          34
# 4694                     10                     NaN         116
# ...                     ...                     ...         ...
# 32425294                 17                    17.0          34
# 32425300                  8                    14.0          34
# 32427098                  9                     3.0        2240
# 32431906                 20                    17.0        1511
# 32431929                  0                    30.0        1511
#
#           add_to_cart_order  reordered product_name  ...  price_range_loc  \
# 2963                      1          0          NaN  ...              NaN
# 3205                      9          1          NaN  ...              NaN
# 3253                      6          0          NaN  ...              NaN
# 3395                      1          1          NaN  ...              NaN
# 4694                     11          0          NaN  ...              NaN
# ...                     ...        ...          ...  ...              ...
# 32425294                  2          1          NaN  ...              NaN
# 32425300                  2          1          NaN  ...              NaN
# 32427098                 18          0          NaN  ...              NaN
# 32431906                  6          0          NaN  ...              NaN
# 32431929                  9          1          NaN  ...              NaN
#
#              busiest_day  busiest_day_new busiest_period_of_day max_order  \
# 2963      Regularly busy       Least busy           Most orders        81
# 3205      Regularly busy   Regularly busy        Average orders        81
# 3253         Busiest day     Busiest days           Most orders        24
# 3395      Regularly busy   Regularly busy        Average orders        24
# 4694         Busiest day     Busiest days           Most orders        12
# ...                  ...              ...                   ...       ...
# 32425294  Regularly busy     Busiest days        Average orders         4
# 32425300  Regularly busy     Busiest days        Average orders         4
# 32427098  Regularly busy   Regularly busy           Most orders        14
# 32431906  Regularly busy     Busiest days        Average orders        11
# 32431929  Regularly busy   Regularly busy         Fewest orders        11
#
#               loyalty_flag avg_spending spending_flag  dspo_median  \
# 2963        Loyal customer     7.659269  High Spender          5.0
# 3205        Loyal customer     7.659269  High Spender          5.0
# 3253      Regular customer     8.355249  High Spender         11.0
# 3395      Regular customer     8.355249  High Spender         11.0
# 4694      Regular customer     8.456477  High Spender         27.0
# ...                    ...          ...           ...          ...
# 32425294      New customer     6.796875  High Spender         17.0
# 32425300      New customer     6.796875  High Spender         17.0
# 32427098  Regular customer     8.151875  High Spender          2.0
# 32431906  Regular customer     7.643200  High Spender         17.0
# 32431929  Regular customer     7.643200  High Spender         17.0
#
#            order_frequency_flag
# 2963          Frequent customer
# 3205          Frequent customer
# 3253           Regular customer
# 3395           Regular customer
# 4694      Non-frequent customer
# ...                         ...
# 32425294       Regular customer
# 32425300       Regular customer
# 32427098      Frequent customer
# 32431906       Regular customer
# 32431929       Regular customer
#
# [30200 rows x 24 columns]

# %%
# check stats of 'left_only' values.
ords_prods_merge['_merge'].value_counts(dropna=False)
# Out:
# _merge
# both         32404859
# left_only       30200
# Name: count, dtype: int64

# %%
# create new df with only results from previous inner merge.
ords_prods_clean = ords_prods_merge[ords_prods_merge['_merge']=='both']
ords_prods_clean['_merge'].value_counts(dropna=False)
# Out:
# _merge
# both    32404859
# Name: count, dtype: int64

# %%
# remove old indicator column from previous merge
ords_prods_clean = ords_prods_clean.drop(columns = ['_merge'])

# %%
# inspect ords_prods after cleaning.
print(ords_prods_clean.shape)
ords_prods_clean.head()
# Out:
# (32404859, 23)
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                   2                  8
# 1   2539329       1             1                   2                  8
# 2   2539329       1             1                   2                  8
# 3   2539329       1             1                   2                  8
# 4   2539329       1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  ...    price_range_loc  \
# 0                                     Soda  ...  Mid-range product
# 1  Organic Unsweetened Vanilla Almond Milk  ...  Mid-range product
# 2                      Original Beef Jerky  ...  Low-range product
# 3               Aged White Cheddar Popcorn  ...  Low-range product
# 4         XL Pick-A-Size Paper Towel Rolls  ...  Low-range product
#
#       busiest_day  busiest_day_new busiest_period_of_day max_order  \
# 0  Regularly busy   Regularly busy        Average orders        10
# 1  Regularly busy   Regularly busy        Average orders        10
# 2  Regularly busy   Regularly busy        Average orders        10
# 3  Regularly busy   Regularly busy        Average orders        10
# 4  Regularly busy   Regularly busy        Average orders        10
#
#    loyalty_flag avg_spending  spending_flag dspo_median   order_frequency_flag
# 0  New customer     6.367797   High Spender        20.5  Non-frequent customer
# 1  New customer     6.367797   High Spender        20.5  Non-frequent customer
# 2  New customer     6.367797   High Spender        20.5  Non-frequent customer
# 3  New customer     6.367797   High Spender        20.5  Non-frequent customer
# 4  New customer     6.367797   High Spender        20.5  Non-frequent customer
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Step 6 (cont.)
# Combine your customer data with the rest of your prepared Instacart data. (Hint: Make sure the key columns are the same data type!)

# %%
# Combine the clean ords_prods df with cleaned customers df
inner_merge = ords_prods_clean.merge(customers_df, on = 'user_id', how = 'inner', indicator = True)
# Out:
# (32404859, 30)

# %%
# Print shape and head to inspect output
print(inner_merge.shape)
inner_merge.head()
# Out:
# (32404859, 30)
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                   2                  8
# 1   2539329       1             1                   2                  8
# 2   2539329       1             1                   2                  8
# 3   2539329       1             1                   2                  8
# 4   2539329       1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  ...  spending_flag  dspo_median  \
# 0                                     Soda  ...   High Spender         20.5
# 1  Organic Unsweetened Vanilla Almond Milk  ...   High Spender         20.5
# 2                      Original Beef Jerky  ...   High Spender         20.5
# 3               Aged White Cheddar Popcorn  ...   High Spender         20.5
# 4         XL Pick-A-Size Paper Towel Rolls  ...   High Spender         20.5
#
#     order_frequency_flag  gender    state age num_depend  fam_status income  \
# 0  Non-frequent customer  Female  Alabama  31          3     married  40423
# 1  Non-frequent customer  Female  Alabama  31          3     married  40423
# 2  Non-frequent customer  Female  Alabama  31          3     married  40423
# 3  Non-frequent customer  Female  Alabama  31          3     married  40423
# 4  Non-frequent customer  Female  Alabama  31          3     married  40423
#
#    _merge
# 0    both
# 1    both
# 2    both
# 3    both
# 4    both
#
# [5 rows x 30 columns]

# %%
# Check results of merge with indicator column
inner_merge['_merge'].value_counts(dropna=False)
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# ### Step 8
# Export this new dataframe as a pickle file so you can continue to use it in the second part of this task.

# %%
# Export combined customers and ords_prods df.
inner_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))

# %%
# Export combined customers and ords_prods df.
customers_df.to_csv(os.path.join(path, '02 Data','Prepared Data', 'customers_checked.csv'))
